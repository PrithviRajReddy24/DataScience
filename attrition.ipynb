# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import seaborn as sns

# %%
IBM = pd.read_csv('IBM Attrition Data.csv')
IBM.head()
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
# 2   37       Yes  Research & Development                 2          2
# 3   33        No  Research & Development                 3          4
# 4   27        No  Research & Development                 2          1
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
# 3  Life Sciences                        4                3       Married
# 4        Medical                        1                2       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# ...

# %%
IBM.describe()
# Out:
#                Age  DistanceFromHome    Education  EnvironmentSatisfaction  \
# count  1470.000000       1470.000000  1470.000000              1470.000000
# mean     36.923810          9.192517     2.912925                 2.721769
# std       9.135373          8.106864     1.024165                 1.093082
# min      18.000000          1.000000     1.000000                 1.000000
# 25%      30.000000          2.000000     2.000000                 2.000000
# 50%      36.000000          7.000000     3.000000                 3.000000
# 75%      43.000000         14.000000     4.000000                 4.000000
# max      60.000000         29.000000     5.000000                 4.000000
#
#        JobSatisfaction  MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  \
# count      1470.000000    1470.000000         1470.000000      1470.000000
# mean          2.728571    6502.931293            2.693197         2.761224
# ...

# %%
IBM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
# Age                        1470 non-null int64
# Attrition                  1470 non-null object
# Department                 1470 non-null object
# DistanceFromHome           1470 non-null int64
# Education                  1470 non-null int64
# EducationField             1470 non-null object
# EnvironmentSatisfaction    1470 non-null int64
# JobSatisfaction            1470 non-null int64
# MaritalStatus              1470 non-null object
# MonthlyIncome              1470 non-null int64
# NumCompaniesWorked         1470 non-null int64
# WorkLifeBalance            1470 non-null int64
# YearsAtCompany             1470 non-null int64
# dtypes: int64(9), object(4)
# memory usage: 149.4+ KB

# %%
IBM.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'WorkLifeBalance', 'YearsAtCompany'],
#       dtype='object')

# %%
attrition = IBM.Attrition.unique()
attrition
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
IBM.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
### Exploratory data Analysis
IBM.groupby('Department').Attrition.value_counts()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# Name: Attrition, dtype: int64

# %%
sns.violinplot(x='Attrition',y='Age',data=IBM)

# %%
sns.violinplot(x='Attrition',y='MonthlyIncome',data=IBM)

# %%
IBM.groupby('Department').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
IBM.groupby('DistanceFromHome').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition               No       Yes
# DistanceFromHome
# 1                 0.875000  0.125000
# 2                 0.867299  0.132701
# 3                 0.833333  0.166667
# 4                 0.859375  0.140625
# 5                 0.846154  0.153846
# 6                 0.881356  0.118644
# 7                 0.869048  0.130952
# 8                 0.875000  0.125000
# 9                 0.788235  0.211765
# 10                0.872093  0.127907
# 11                0.862069  0.137931
# 12                0.700000  0.300000
# 13                0.684211  0.315789
# 14                0.809524  0.190476
# 15                0.807692  0.192308
# 16                0.781250  0.218750
# 17                0.750000  0.250000
# 18                0.846154  0.153846
# 19                0.863636  0.136364
# 20                0.840000  0.160000
# 21                0.833333  0.166667
# 22                0.684211  0.315789
# 23                0.814815  0.185185
# 24                0.571429  0.428571
# ...

# %%
IBM.groupby('Education').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition        No       Yes
# Education
# 1          0.817647  0.182353
# 2          0.843972  0.156028
# 3          0.826923  0.173077
# 4          0.854271  0.145729
# 5          0.895833  0.104167

# %%
IBM.groupby('EducationField').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition               No       Yes
# EducationField
# Human Resources   0.740741  0.259259
# Life Sciences     0.853135  0.146865
# Marketing         0.779874  0.220126
# Medical           0.864224  0.135776
# Other             0.865854  0.134146
# Technical Degree  0.757576  0.242424

# %%
IBM.groupby('EnvironmentSatisfaction').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition                      No       Yes
# EnvironmentSatisfaction
# 1                        0.746479  0.253521
# 2                        0.850174  0.149826
# 3                        0.863135  0.136865
# 4                        0.865471  0.134529

# %%
IBM.groupby('JobSatisfaction').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition              No       Yes
# JobSatisfaction
# 1                0.771626  0.228374
# 2                0.835714  0.164286
# 3                0.834842  0.165158
# 4                0.886710  0.113290

# %%
IBM.groupby('MaritalStatus').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition            No       Yes
# MaritalStatus
# Divorced       0.899083  0.100917
# Married        0.875186  0.124814
# Single         0.744681  0.255319

# %%
IBM.groupby('NumCompaniesWorked').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition                 No       Yes
# NumCompaniesWorked
# 0                   0.883249  0.116751
# 1                   0.811900  0.188100
# 2                   0.890411  0.109589
# 3                   0.899371  0.100629
# 4                   0.877698  0.122302
# 5                   0.746032  0.253968
# 6                   0.771429  0.228571
# 7                   0.770270  0.229730
# 8                   0.877551  0.122449
# 9                   0.769231  0.230769

# %%
IBM.groupby('WorkLifeBalance').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition              No       Yes
# WorkLifeBalance
# 1                0.687500  0.312500
# 2                0.831395  0.168605
# 3                0.857783  0.142217
# 4                0.823529  0.176471

# %%
IBM.groupby('YearsAtCompany').Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition             No       Yes
# YearsAtCompany
# 0               0.636364  0.363636
# 1               0.654971  0.345029
# 2               0.787402  0.212598
# 3               0.843750  0.156250
# 4               0.827273  0.172727
# 5               0.892857  0.107143
# 6               0.881579  0.118421
# 7               0.877778  0.122222
# 8               0.887500  0.112500
# 9               0.902439  0.097561
# 10              0.850000  0.150000
# 11              0.937500  0.062500
# 12              1.000000       NaN
# 13              0.916667  0.083333
# 14              0.888889  0.111111
# 15              0.950000  0.050000
# 16              0.916667  0.083333
# 17              0.888889  0.111111
# 18              0.923077  0.076923
# 19              0.909091  0.090909
# 20              0.962963  0.037037
# 21              0.928571  0.071429
# 22              0.933333  0.066667
# 23              0.500000  0.500000
# 24              0.833333  0.166667
# ...

# %%
IBM.groupby(['Department','MaritalStatus']).Attrition.value_counts(normalize=True).unstack()
# Out:
# Attrition                                   No       Yes
# Department             MaritalStatus
# Human Resources        Divorced       0.687500  0.312500
#                        Married        0.823529  0.176471
#                        Single         0.923077  0.076923
# Research & Development Divorced       0.919643  0.080357
#                        Married        0.886836  0.113164
#                        Single         0.782895  0.217105
# Sales                  Divorced       0.885057  0.114943
#                        Married        0.859223  0.140777
#                        Single         0.653595  0.346405

# %%
## Histogram
IBM.Age.hist(bins=70)
plt.title('Age destribution of employes')
plt.xlabel('Age')
plt.ylabel('destribution')
# Out:
# Text(0, 0.5, 'destribution')

# %%
IBM.Attrition.value_counts().plot('bar')
plt.show()
# Out:
# C:\Users\PRITHVIRAJ REDDY\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
IBM.EducationField.value_counts().plot('bar')
plt.show()
# Out:
# C:\Users\PRITHVIRAJ REDDY\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
IBM.MaritalStatus.value_counts().plot('bar')
plt.show()
# Out:
# C:\Users\PRITHVIRAJ REDDY\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
IBM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
# Age                        1470 non-null int64
# Attrition                  1470 non-null object
# Department                 1470 non-null object
# DistanceFromHome           1470 non-null int64
# Education                  1470 non-null int64
# EducationField             1470 non-null object
# EnvironmentSatisfaction    1470 non-null int64
# JobSatisfaction            1470 non-null int64
# MaritalStatus              1470 non-null object
# MonthlyIncome              1470 non-null int64
# NumCompaniesWorked         1470 non-null int64
# WorkLifeBalance            1470 non-null int64
# YearsAtCompany             1470 non-null int64
# dtypes: int64(9), object(4)
# memory usage: 149.4+ KB

# %%
IBM.corr()
# Out:
#                               Age  DistanceFromHome  Education  \
# Age                      1.000000         -0.001686   0.208034
# DistanceFromHome        -0.001686          1.000000   0.021042
# Education                0.208034          0.021042   1.000000
# EnvironmentSatisfaction  0.010146         -0.016075  -0.027128
# JobSatisfaction         -0.004892         -0.003669  -0.011296
# MonthlyIncome            0.497855         -0.017014   0.094961
# NumCompaniesWorked       0.299635         -0.029251   0.126317
# WorkLifeBalance         -0.021490         -0.026556   0.009819
# YearsAtCompany           0.311309          0.009508   0.069114
#
#                          EnvironmentSatisfaction  JobSatisfaction  \
# Age                                     0.010146        -0.004892
# DistanceFromHome                       -0.016075        -0.003669
# Education                              -0.027128        -0.011296
# EnvironmentSatisfaction                 1.000000        -0.006784
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(IBM.corr(),annot=True)

# %%
IBM.Attrition.replace('Yes',1,inplace=True)

IBM.Attrition.replace('No',0,inplace=True)

# %%
IBM.head(3)
# Out:
#    Age  Attrition              Department  DistanceFromHome  Education  \
# 0   41          1                   Sales                 1          2
# 1   49          0  Research & Development                 8          1
# 2   37          1  Research & Development                 2          2
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# 0           5993                   8                1               6
# 1           5130                   1                3              10
# 2           2090                   6                3               0

# %%
IBM.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
IBM.Department.replace('Research & Development',1,inplace=True)
IBM.Department.replace('Sales',2,inplace=True)
IBM.Department.replace('Human Resources',3,inplace=True)

# %%
IBM.EducationField.value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
IBM.EducationField.replace('Life Sciences',1,inplace=True)
IBM.EducationField.replace('Medical',2,inplace=True)
IBM.EducationField.replace('Marketing',3,inplace=True)
IBM.EducationField.replace('Technical Degree',4,inplace=True)
IBM.EducationField.replace('Other',5,inplace=True)
IBM.EducationField.replace('Human Resources',6,inplace=True)

# %%
IBM.MaritalStatus.value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
IBM.MaritalStatus.replace('Married',1,inplace=True)
IBM.MaritalStatus.replace('Single',2,inplace=True)
IBM.MaritalStatus.replace('Divorced',3,inplace=True)

# %%
IBM.head()
# Out:
#    Age  Attrition  Department  DistanceFromHome  Education  EducationField  \
# 0   41          1           2                 1          2               1
# 1   49          0           1                 8          1               1
# 2   37          1           1                 2          2               5
# 3   33          0           1                 3          4               1
# 4   27          0           1                 2          1               2
#
#    EnvironmentSatisfaction  JobSatisfaction  MaritalStatus  MonthlyIncome  \
# 0                        2                4              2           5993
# 1                        3                2              1           5130
# 2                        4                3              2           2090
# 3                        4                3              1           2909
# 4                        1                2              1           3468
#
#    NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# ...

# %%
IBM.corr()
# Out:
#                               Age  Attrition  Department  DistanceFromHome  \
# Age                      1.000000  -0.159205   -0.007652         -0.001686
# Attrition               -0.159205   1.000000    0.077351          0.077924
# Department              -0.007652   0.077351    1.000000          0.002196
# DistanceFromHome        -0.001686   0.077924    0.002196          1.000000
# Education                0.208034  -0.031373    0.019636          0.021042
# EducationField          -0.030912   0.062320    0.253737          0.006907
# EnvironmentSatisfaction  0.010146  -0.103369   -0.026110         -0.016075
# JobSatisfaction         -0.004892  -0.103481   -0.006231         -0.003669
# MaritalStatus           -0.035466   0.011195   -0.030818         -0.021916
# MonthlyIncome            0.497855  -0.159840    0.056573         -0.017014
# NumCompaniesWorked       0.299635   0.043494   -0.011261         -0.029251
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(IBM.corr(),annot=True)

# %%
IBM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
# Age                        1470 non-null int64
# Attrition                  1470 non-null int64
# Department                 1470 non-null int64
# DistanceFromHome           1470 non-null int64
# Education                  1470 non-null int64
# EducationField             1470 non-null int64
# EnvironmentSatisfaction    1470 non-null int64
# JobSatisfaction            1470 non-null int64
# MaritalStatus              1470 non-null int64
# MonthlyIncome              1470 non-null int64
# NumCompaniesWorked         1470 non-null int64
# WorkLifeBalance            1470 non-null int64
# YearsAtCompany             1470 non-null int64
# dtypes: int64(13)
# memory usage: 149.4 KB

# %%
x = IBM[['Department','DistanceFromHome','EducationField','MaritalStatus','NumCompaniesWorked']]
y = IBM['Attrition']
